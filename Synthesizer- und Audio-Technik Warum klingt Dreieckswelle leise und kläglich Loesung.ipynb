# %% [markdown]
# ---
# blogpost: true
# date: Oct 01, 2034
# location: Lösung
# category: Übung
# tags: Dreieck, Sägezahn, Rechteck, Fourier-Reihe, Audio-Technik, Signal, Aliasing, Abtastung
# ---
#
# # Synthesizer- und Audio-Technik: Warum klingt Dreieckswelle leise und kläglich?: Lösung
